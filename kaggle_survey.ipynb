# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
pd.set_option("display.max_columns",None)

# %%
data=pd.read_csv("kaggle_survey_2020_responses.csv")
# Out:
# C:\Users\Daniel\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.head()
# Out:
#   Time from Start to Finish (seconds)                           Q1  \
# 0               Duration (in seconds)  What is your age (# years)?
# 1                                1838                        35-39
# 2                              289287                        30-34
# 3                                 860                        35-39
# 4                                 507                        30-34
#
#                                        Q2  \
# 0  What is your gender? - Selected Choice
# 1                                     Man
# 2                                     Man
# 3                                     Man
# 4                                     Man
#
#                                           Q3  \
# 0  In which country do you currently reside?
# 1                                   Colombia
# 2                   United States of America
# 3                                  Argentina
# 4                   United States of America
#
# ...

# %%
data.shape
# Out:
# (20037, 355)

# %%
null_feat=[i for i in data.columns if data[i].isnull().sum()>0]

# %%
len(null_feat)
# Out:
# 351

# %%
len(data)
# Out:
# 20037

# %%
nullfeat_percent=[(i, (data[i].isnull().sum()/len(data))*100) for i in data.columns if data[i].isnull().sum()>0]

[nullfeat_percent]
# Out:
# [[('Q4', 2.330688226780456),
#   ('Q5', 3.7879922144033538),
#   ('Q6', 4.571542646104707),
#   ('Q7_Part_1', 22.488396466536905),
#   ('Q7_Part_2', 78.64949842790837),
#   ('Q7_Part_3', 62.389579278335084),
#   ('Q7_Part_4', 83.45061635973448),
#   ('Q7_Part_5', 80.89534361431352),
#   ('Q7_Part_6', 83.19109647152767),
#   ('Q7_Part_7', 85.0476618256226),
#   ('Q7_Part_8', 98.68742825772321),
#   ('Q7_Part_9', 99.00683735090084),
#   ('Q7_Part_10', 91.13140689724011),
#   ('Q7_Part_11', 88.93047861456306),
#   ('Q7_Part_12', 98.96691121425363),
#   ('Q7_OTHER', 90.28796726056795),
#   ('Q8', 11.05454908419424),
#   ('Q9_Part_1', 44.04351948894545),
#   ('Q9_Part_2', 80.90033438139443),
#   ('Q9_Part_3', 87.79258372011778),
#   ('Q9_Part_4', 70.68423416679144),
#   ('Q9_Part_5', 74.5470878874083),
#   ('Q9_Part_6', 83.575385536757),
#   ('Q9_Part_7', 84.36392673553925),
#   ('Q9_Part_8', 87.75764835055148),
#   ('Q9_Part_9', 92.49887707740679),
#   ('Q9_Part_10', 91.98981883515496),
# ...

# %%
data["Q7_Part_7"]
# Out:
# 0        What programming languages do you use on a reg...
# 1                                               Javascript
# 2                                                      NaN
# 3                                               Javascript
# 4                                                      NaN
#                                ...
# 20032                                                  NaN
# 20033                                                  NaN
# 20034                                                  NaN
# 20035                                           Javascript
# 20036                                                  NaN
# Name: Q7_Part_7, Length: 20037, dtype: object
